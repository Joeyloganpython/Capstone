# %% [markdown]
# # Setup

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from collections import defaultdict, Counter
import matplotlib.pyplot as plt
from matplotlib import style
import datetime
import seaborn as sns

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv('../data/Pulled/Dispensation_Data_without_Buprenorphine_Quarter_3_2016_-_Current_Quarterly_County_Health.csv')

###Keeping age groups, removing all ages ## will have to do Genders seperatly as 
##They don't count them together
dfage = df[df['Age Group'] != 'All Ages']

dfage.head()
# Out:
#   County Name  Rate or Count  \
# 0      Warren         156.00
# 1      Carbon        3017.03
# 3       Wayne        3113.00
# 4   Lancaster         403.00
# 5     Chester       19635.00
#
#                                   Type of Drug Class  \
# 0  Opioids (All Schedules) - excluding Buprenorphine
# 1  Opioids (All Schedules) - excluding Buprenorphine
# 3  Opioids (All Schedules) - excluding Buprenorphine
# 4  Opioids (All Schedules) - excluding Buprenorphine
# 5  Opioids (All Schedules) - excluding Buprenorphine
#
#                        Type of Rate or Count Measure Age Group       Gender  \
# 0     Number of Dispensations (by pharmacy location)     15-24  All Genders
# 1  Rate of Prescriptions (by patient location) pe...     35-44  All Genders
# 3     Number of Dispensations (by pharmacy location)     55-64  All Genders
# 4     Number of Dispensations (by pharmacy location)      0-14  All Genders
# 5     Number of Dispensations (by pharmacy location)       65+  All Genders
#
#        Time Measure  Year Time Period Quarter Date Start Notes  \
# 0  Quarterly Counts  2017     2017 Q4         10/01/2017   NaN
# 1   Quarterly Rates  2016     2016 Q3         07/01/2016   NaN
# 3  Quarterly Counts  2016     2016 Q3         07/01/2016   NaN
# 4  Quarterly Counts  2017     2017 Q4         10/01/2017   NaN
# 5  Quarterly Counts  2018     2018 Q1         01/01/2018   NaN
#
#    County Code Number  County Code Text  State FIPS Code  County FIPS Code  \
# 0                  62                62               42               123
# 1                  13                13               42                25
# 3                  64                64               42               127
# 4                  36                36               42                71
# 5                  15                15               42                29
#
#     Latitude  Longitude Georeferenced Latitude & Longitude
# 0  41.816752 -79.278582   POINT (-79.27858158 41.81675237)
# 1  40.919367 -75.711070   POINT (-75.71107039 40.91936701)
# 3  41.649698 -75.305154    POINT (-75.3051535 41.64969805)
# 4  40.045908 -76.251388   POINT (-76.25138768 40.04590796)
# 5  39.974871 -75.756265   POINT (-75.75626498 39.97487056)

# %% [markdown]
# # Plots

# %%
plt.rcParams["figure.figsize"] = (20,12)
sns.set(font_scale = 2)
dfage.groupby(['Year', 'Age Group'])['Rate or Count'].mean().unstack().plot.bar(fontsize=16)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(xlabel = 'Year', fontsize=20)
plt.ylabel(ylabel = 'Amount Dispensed', fontsize=20)
plt.legend(borderpad=.5, labelspacing=.8,handlelength=1,fontsize = 11, title = 'Age Range')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (20,8)
sns.set(font_scale = 2)
dfage.groupby('Age Group')['Rate or Count'].mean().plot.bar(fontsize=16)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(xlabel = 'Age Range', fontsize=20)
plt.ylabel(ylabel = 'Amount Dispensed', fontsize=20)
plt.show()

# %%
### Showing an upward trend with age

# %%
plt.rcParams["figure.figsize"] = (20,8)
sns.set(font_scale = 2)
dfage.groupby('Year')['Rate or Count'].mean().plot.bar(fontsize=16)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel(xlabel = 'Year', fontsize=20)
plt.ylabel(ylabel = 'Amount Dispensed', fontsize=20)
plt.show()

# %%
### Showing a downward trend with dispensing

# %% [markdown]
# <h2> By Gender

# %%
df.head()
# Out:
#   County Name  Rate or Count  \
# 0      Warren         156.00
# 1      Carbon        3017.03
# 2      Monroe       28610.00
# 3       Wayne        3113.00
# 4   Lancaster         403.00
#
#                                   Type of Drug Class  \
# 0  Opioids (All Schedules) - excluding Buprenorphine
# 1  Opioids (All Schedules) - excluding Buprenorphine
# 2  Opioids (All Schedules) - excluding Buprenorphine
# 3  Opioids (All Schedules) - excluding Buprenorphine
# 4  Opioids (All Schedules) - excluding Buprenorphine
#
#                        Type of Rate or Count Measure Age Group       Gender  \
# 0     Number of Dispensations (by pharmacy location)     15-24  All Genders
# 1  Rate of Prescriptions (by patient location) pe...     35-44  All Genders
# 2     Number of Dispensations (by pharmacy location)  All Ages  All Genders
# 3     Number of Dispensations (by pharmacy location)     55-64  All Genders
# 4     Number of Dispensations (by pharmacy location)      0-14  All Genders
#
#        Time Measure  Year Time Period Quarter Date Start Notes  \
# 0  Quarterly Counts  2017     2017 Q4         10/01/2017   NaN
# 1   Quarterly Rates  2016     2016 Q3         07/01/2016   NaN
# 2  Quarterly Counts  2017     2017 Q2         04/01/2017   NaN
# 3  Quarterly Counts  2016     2016 Q3         07/01/2016   NaN
# 4  Quarterly Counts  2017     2017 Q4         10/01/2017   NaN
#
#    County Code Number  County Code Text  State FIPS Code  County FIPS Code  \
# 0                  62                62               42               123
# 1                  13                13               42                25
# 2                  45                45               42                89
# 3                  64                64               42               127
# 4                  36                36               42                71
#
#     Latitude  Longitude Georeferenced Latitude & Longitude
# 0  41.816752 -79.278582   POINT (-79.27858158 41.81675237)
# 1  40.919367 -75.711070   POINT (-75.71107039 40.91936701)
# 2  41.060918 -75.340836   POINT (-75.34083603 41.06091787)
# 3  41.649698 -75.305154    POINT (-75.3051535 41.64969805)
# 4  40.045908 -76.251388   POINT (-76.25138768 40.04590796)

# %%
df_gender = df[df['Gender'] != 'All Genders']

# %%
plt.rcParams["figure.figsize"] = (20,10)
sns.set(font_scale = 2)
df_gender.groupby(['Year', 'Gender'])['Rate or Count'].mean().unstack().plot.bar(fontsize=16)
plt.xticks(rotation=45,fontsize=16)
plt.yticks(fontsize=16)
plt.xlabel(xlabel = 'Year', fontsize=16)
plt.ylabel(ylabel = 'Amount Dispensed', fontsize=16)
plt.legend(borderpad=.5, labelspacing=1.1,handlelength=1,fontsize = 16, title = 'Gender')
plt.show()

# %%
### Females are dispenced more often in neach year
##Both groups maintain a downward trend at about  the same level
